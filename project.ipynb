# %%
import sys
# !{sys.executable} -m pip install pymysql sqlalchemy psycopg2-binary
# Out:
# ...
#   Using cached pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached psycopg2_binary-2.9.12-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached greenlet-3.4.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached pymysql-1.1.2-py3-none-any.whl (45 kB)
# Using cached sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached psycopg2_binary-2.9.12-cp312-cp312-win_amd64.whl (2.8 MB)
# Using cached greenlet-3.4.0-cp312-cp312-win_amd64.whl (238 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Riddhi\Desktop\project-walmart\my_env1\Scripts\python.exe

# %%
import zipfile

with zipfile.ZipFile("walmart-10k-sales-datasets.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %% [markdown]
# steps 1 data exploration and leading

# %%
#importing dependencies

import pandas as pd
#mysql toolkit
import pymysql
from sqlalchemy  import create_engine

import psycopg2

# %%
import pymysql
import sqlalchemy
import psycopg2

print("All good ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pymysql
#       2 import sqlalchemy
#       3 import psycopg2
#       4
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
import pymysql
print("Installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pymysql
#       2 print("Installed successfully!")
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
print(pd.__version__)
# Out:
# 3.0.2

# %%
df = pd.read_csv('Walmart.csv', encoding_errors='ignore')

df.shape
# Out:
# (10051, 11)

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(51)

# %%
df.drop_duplicates(inplace=True)
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
#dropping all rows with missing records
df.dropna(inplace=True)

#verify
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 11)

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch                str
# City                  str
# category              str
# unit_price            str
# quantity          float64
# date                  str
# time                  str
# payment_method        str
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df['unit_price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df['unit_price'].astype(float)
#
# File c:\Users\Riddhi\Desktop\project-walmart\my_env1\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File c:\Users\Riddhi\Desktop\project-walmart\my_env1\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
# ...

# %%
df['unit_price']=df['unit_price'].str.replace('$',' ').astype(float)
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9969 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   Branch          9969 non-null   str
#  2   City            9969 non-null   str
#  3   category        9969 non-null   str
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   str
#  7   time            9969 non-null   str
#  8   payment_method  9969 non-null   str
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
# dtypes: float64(4), int64(1), str(6)
# memory usage: 934.6 KB

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='str')

# %%
df['total'] = df['unit_price'] * df['quantity']
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin   total
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48  522.83
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48   76.40
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33  324.31
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33  465.76
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48  604.17
